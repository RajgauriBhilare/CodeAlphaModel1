# %%
1-2
# Out:
# -1

# %%
3*5
# Out:
# 15

# %%
5/22
# Out:
# 0.22727272727272727

# %%
15/3
# Out:
# 5.0

# %%
10**2
# Out:
# 100

# %%
10 * 'a'
# Out:
# 'aaaaaaaaaa'

# %%
type(2)
# Out:
# int

# %%
type("hi")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type(10.2)
# Out:
# float

# %%
a=10
a
# Out:
# 10

# %%
firstname="rajgauri"
lastname="bhilare"
print(firstname,lastname)
# Out:
# rajgauri bhilare

# %%
print("my name {} ans surname is {}".format(firstname,lastname))
# Out:
# my name rajgauri ans surname is bhilare

# %%
my_str="rajgauri"

# %%
my_str.isalnum()
# Out:
# True
