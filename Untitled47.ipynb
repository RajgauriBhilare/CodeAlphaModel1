# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data_set=pd.read_csv("C:/Users/Rajguru/Downloads/MBA.csv")

#independent nd dependent varaible  extracting
x=data_set.iloc[:,[2,3]].values
y=data_set.iloc[:,4].values

#splitting dataset into train and test 
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

#feature scaling
from sklearn.preprocessing import StandardScaler
st_x=StandardScaler()
x_train=st_x.fit_transform(x_train)
x_test=st_x.transform(x_test)

#fitting  knn clasiifer into trainning set
from sklearn.neighbors import KNeighborsClassifier
classifier=KNeighborsClassifier(n_neighbors=5,metric='minkowski',p=2)
classifier.fit(x_train,y_train)

#predict the test set result
y_pred=classifier.predict(x_test)
print(y_pred)

#confusion matrix

from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# ['Humanities' 'Business' 'STEM' ... 'Humanities' 'Business' 'Business']
# [[167 195  69]
#  [218 269 104]
#  [178 255  94]]

# %%
graph={
    'A':['B','C'],
    'B':['D','E'],
    'C':['F','G'],
    'D':[],
    'E':[],
    'F':[],
    'G':[]
}

def bfs(node):
    visited=[False]*(len(graph))
    queue=[]
    visited.append(node)
    queue.append(node)
    while queue:
        v=queue.pop(0)             #dequeue
        print(v,end="")
        for neigh in graph[v]:
            if neigh not in visited:
                visited.append(neigh)
                queue.append(neigh)

if __name__ == "__main__":
    bfs('A')
# Out:
# ABCDEFG

# %%
graph={
    'A':['B','C'],
    'B':['D','E'],
    'C':['F','G'],
    'D':[],
    'E':[],
    'F':[],
    'G':[]
}
def bfs(node):
    visited=[False]*len(graph)
    queue=[]
    visited.append(node)
    queue.append(node)
    while queue:
        v=queue.pop(0)
        print(v,end="")
        for neigh in graph[v]:
            if neigh not in visited:
                visited.append(neigh)
                queue.append(neigh)


if __name__ == "__main__":
    bfs('A')
# Out:
# ABCDEFG

# %%
graph={
    'S':['A','H'],
    'A':['B','C'],
    'H':['I','J'],
    'B':['D','E'],
    'C':['G'],
    'I':['K'],
    'J':[],
    'D':[],
    'E':[],
    'G':[],
    'K':[]
}

visited=set()
def dfs(visited,graph,node):
    if node not in visited:
        print(node,"---",end="")
        visited.add(node)
        for neighbour in graph[node]:
            dfs(visited,graph,neighbour)
print("Following is the Depth first serach")
dfs(visited,graph,'S')
# Out:
# Following is the Depth first serach
# S ---A ---B ---D ---E ---C ---G ---H ---I ---K ---J ---

# %%
graph={
    'S':['A','H'],
    'A':['B','C'],
    'H':['I','J'],
    'B':['D','E'],
    'C':['G'],
    'I':['K'],
    'J':[],
    'D':[],
    'E':[],
    'G':[],
    'K':[]
}

visited=set()
def dfs(visited,graph,node):
    if node not in visited:
        print(node,"----",end="")
        visited.add(node)
        for neighbour in graph[node]:
            dfs(visited,graph,neighbour)
print("following depth first serach is")
dfs(visited,graph,'S')
# Out:
# following depth first serach is
# S ----A ----B ----D ----E ----C ----G ----H ----I ----K ----J ----

# %%
import random
import pyttsx3

# %%
pip install  pyttsx3
# Out:
# ...
#    ---------------------------------------- 0.0/229.4 kB ? eta -:--:--
#    ---------------------------------------- 229.4/229.4 kB 4.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install random
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement random (from versions: none)
# ERROR: No matching distribution found for random

# %%
import random
import pyttsx3

# Initialize the text-to-speech engine
engine = pyttsx3.init()

# Function to make the chatbot speak
def speak(text):
    engine.say(text)
    engine.runAndWait()

# Predefined responses
responses = {
    "hello": ["Hi there!", "Hello!", "Hey! How can I assist you?"],
    "how are you": ["I'm just a bot, but I'm doing great!", "I'm here to help you! How can I assist?"],
    "your name": ["I'm ChatBot! What's your name?", "I'm your friendly chatbot. What's up?"],
    "weather": ["I can't check the weather right now, but it’s always a good day to chat!", "It’s sunny somewhere, I bet!"],
    "bye": ["Goodbye! Have a great day!", "Bye! Take care!", "See you next time!"],
    "default": ["I'm sorry, I didn't quite get that.", "Can you rephrase that?", "I'm here to help! Could you clarify?"]
}

# Function to generate a response
def get_response(user_input):
    user_input = user_input.lower()  # Convert input to lowercase for uniformity
    for key in responses:
        if key in user_input:
            return random.choice(responses[key])  # Return a random response for variety
    return random.choice(responses["default"])  # Default response if no keyword matches

# Main chatbot loop
def chatbot():
    print("ChatBot: Hello! I'm your friendly chatbot. Type 'bye' to exit.")
    speak("Hello! I'm your friendly chatbot. Type 'bye' to exit.")
    while True:
        user_input = input("You: ")  # Get input from the user
        if "bye" in user_input.lower():
            farewell = random.choice(responses["bye"])
            print("ChatBot:", farewell)
            speak(farewell)
            break
        response = get_response(user_input)  # Get the chatbot's response
        print("ChatBot:", response)
        speak(response)  # Speak the response

# Run the chatbot
if __name__ == "__main__":
    chatbot()
# Out:
# ChatBot: Hello! I'm your friendly chatbot. Type 'bye' to exit.
# You:  hello
# ChatBot: Hey! How can I assist you?
# You:  how are you
# ChatBot: I'm here to help you! How can I assist?
# You:  give me colrs name
# ChatBot: I'm here to help! Could you clarify?

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# Load dataset
df = pd.read_csv("C:/Users/Rajguru/Downloads/Salary.csv")
print(df)
# Define features (x) and target (y)
x = df.iloc[:, :-1].values  # All columns except the last one (assuming the last is the target)
y = df.iloc[:, -1].values   # The last column as target

# Split the dataset into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=1/3, random_state=0)

# Instantiate and train the Linear Regression model
regressor = LinearRegression()
regressor.fit(x_train, y_train)

# Predict test set results
y_pred = regressor.predict(x_test)

# Visualize Training Set Results
plt.scatter(x_train, y_train, color='red', label='Actual')
plt.plot(x_train, regressor.predict(x_train), color='blue', label='Predicted')
plt.title('Training Set: Actual vs Predicted')
plt.xlabel('Features')
plt.ylabel('Target')
plt.legend()
plt.show()

# Visualize Test Set Results
plt.scatter(x_test, y_test, color='green', label='Actual')
plt.plot(x_test, y_pred, color='blue', label='Predicted')
plt.title('Test Set: Actual vs Predicted')
plt.xlabel('Features')
plt.ylabel('Target')
plt.legend()
plt.show()
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872
# 30             11.2  127345
# 31             11.5  126756
# ...

# %%
def hanoi(n,f,to,via):
    if n==1:
        print("move disk 1 from to",f,"to",to);
    else:
        hanoi(n-1,f,via,to)
        print("move disk",n,"from",f,"to",to);
        hanoi(n-1,via,to,f)
n=3
f='A'
to='B'
hanoi(n,f,to,via)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 11
#       9 f='A'
#      10 to='B'
# ---> 11 hanoi(n,f,to,via)
#
# NameError: name 'via' is not defined

# %%
def hanoi(n, f, to, via):
    if n == 1:
        print("Move disk 1 from", f, "to", to)
    else:
        hanoi(n - 1, f, via, to)
        print("Move disk", n, "from", f, "to", to)
        hanoi(n - 1, via, to, f)

# Number of disks
n =4 
# Tower names: A = source, B = destination, C = auxiliary
f = 'A'  # Source tower
to = 'B'  # Destination tower
via = 'C'  # Auxiliary tower

# Function call
hanoi(n, f, to, via)
# Out:
# Move disk 1 from A to C
# Move disk 2 from A to B
# Move disk 1 from C to B
# Move disk 3 from A to C
# Move disk 1 from B to A
# Move disk 2 from B to C
# Move disk 1 from A to C
# Move disk 4 from A to B
# Move disk 1 from C to B
# Move disk 2 from C to A
# Move disk 1 from B to A
# Move disk 3 from C to B
# Move disk 1 from A to C
# Move disk 2 from A to B
# Move disk 1 from C to B

# %%
def hanoi(n,f,sec,via):
    if n==1:
        print("move disk 1 from",f,"to",sec)
    else:
        hanoi(n-1,f,via,sec)
        print("moe disk",n,"from",f,"to",sec)
        hanoi(n-1,via,sec,f)
n=3
f='A'
sec='B'
via='C'
hanoi(n,f,sec,via)
# Out:
# move disk 1 from A to B
# moe disk 2 from A to C
# move disk 1 from B to C
# moe disk 3 from A to B
# move disk 1 from C to A
# moe disk 2 from C to B
# move disk 1 from A to B

# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
from nltk.chat.util import chat,reflections

chatbot_responses=[
    [r",hello|hii|hey",
     ["hello!","hii!","hey!"]
    ],
    [r"how are you?",
     ["i am good ,thanks","i am doing well,how about you?"]
    ],
    [r"bye|goodbye",
     ["Goodbye!","Bye!","TAke care!"]
    ]]
chatbot=chat(chatbot_responses,reflections)
print("Hello i am simple.You can type 'exit' to end the conversation")
while True:
    user_input=input("enter your message")
    if user_input.lower()=="exit":
        print("chatbot:Goodbye!")
        break
    response=chatbot.respond(user_input)
    print("chatbot",response)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[41], line 2
#       1 import nltk
# ----> 2 from nltk.chat.util import chat,reflections
#       4 chatbot_responses=[
#       5     [r",hello|hii|hey",
#       6      ["hello!","hii!","hey!"]
#    (...)
#      12      ["Goodbye!","Bye!","TAke care!"]
#      13     ]]
#      14 chatbot=chat(chatbot_responses,reflections)
#
# ImportError: cannot import name 'chat' from 'nltk.chat.util' (C:\Users\Rajguru\anaconda3\Lib\site-packages\nltk\chat\util.py)
