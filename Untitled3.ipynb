# %%
x=5
y=3
print(x+y)
# Out:
# 8

# %%
x=5
y=3
print(x-y)
# Out:
# 2

# %%
x=5
y=3
print(x*y)
# Out:
# 15

# %%
x=5
y=3
print(x/y)
# Out:
# 1.6666666666666667

# %%
x=5
y=3
print(x%y)
# Out:
# 2

# %%
x=5
y=3
print(x**y)
# Out:
# 125

# %%
x=5
y=3
print(x//y)
# Out:
# 1

# %%
x=5
x+=3
print(x)
# Out:
# 8

# %%
x=5
x-=3
print(x)
# Out:
# 2

# %%
x=5
x*=3
print(x)
# Out:
# 15

# %%
x=5
x/=3
print(x)
# Out:
# 1.6666666666666667

# %%
x=5
x%=3
print(x)
# Out:
# 2

# %%
x=5
x//=3
print(x)
# Out:
# 1

# %%
x=5
x**=3
print(x)
# Out:
# 125

# %%
x=5
x&=3
print(x)
# Out:
# 1

# %%
x=5
x|=3
print(x)
# Out:
# 7

# %%
x=5
x^=3
print(x)
# Out:
# 6

# %%
x=5
x>>=3
print(x)
# Out:
# 0

# %%
x=5
x<<=3
print(x)
# Out:
# 40

# %%
x=5
x:=3
print(x)
# Out:
#   Cell In[21], line 2
#     x:=3
#      ^
# SyntaxError: invalid syntax

# %%
x=5
x=x+3
print(x)
# Out:
# 8

# %%
x=5
x=x-3
print(x)
# Out:
# 2

# %%
x=5
x=x*3
print(x)
# Out:
# 15

# %%
x=5
x=x/3
print(x)
# Out:
# 1.6666666666666667

# %%
x=5
x=x**3
print(x)
# Out:
# 125

# %%
x=5
x=x%3
print(x)
# Out:
# 2

# %%
x=5
x=x//3
print(x)
# Out:
# 1

# %%
x=5
x=x&3
print(x)
# Out:
# 1

# %%
x=5
x=x^3
print(x)
# Out:
# 6

# %%
x=5
x=x>>3
print(x)
# Out:
# 0

# %%
x=5
x=x<<3
print(x)
# Out:
# 40

# %%
x=5
x=3
print(x)
# Out:
# 3

# %%
x=5
y=3
print(x==y)
# Out:
# False

# %%
x=5
y=3
print(x!=y)
# Out:
# True

# %%
x=5
y=3
print(x>y)
# Out:
# True

# %%
x=5
y=3
print(x<y)
# Out:
# False

# %%
x=5
y=3
print(x>=y)
# Out:
# True

# %%
x=5
y=3
print(x<=y)
# Out:
# False

# %%
x=5
y=3
print(x==y)
# Out:
# False

# %%
x=5
print(x>3 and x<10)
# Out:
# True

# %%
cars=["ford","volvo","bmw"]
print(cars)
# Out:
# ['ford', 'volvo', 'bmw']

# %%
cars=["ford","volvo","bmw"]
cars[0]="toyata"
print(cars)
# Out:
# ['toyata', 'volvo', 'bmw']

# %%
a=33
b=200
if b>a:
    print("b is greater than a")
# Out:
# b is greater than a

# %%
a=33
b=200
if a>b:
    print("a is greater than b")

# %%
a=33
b=200
if b>a:
    print("b is greater than a")
elif a==b:
    print("a and b equal")
# Out:
# b is greater than a

# %%
a=200
b=33
if b>a:
    print("b is greater than a")
elif a==b:
    print("a and b equal")
else:
    print("a is greater than b")
# Out:
# a is greater than b

# %%
a=200
b=33
if b>a:
    print("b is greater than a")
else:
    print("b is not grater than a")
# Out:
# b is not grater than a

# %%
a=200
b=33
c=500
if a>b and c>a:
    print("both condition are true")
# Out:
# both condition are true

# %%
a=200
b=33
c=500
if a>b and c>a:
    print("at least one of the condition is true")
# Out:
# at least one of the condition is true

# %%
a=33
b=200
if not a>b:
    print("a is not grater than b")
# Out:
# a is not grater than b

# %%
x=41
if x>10:
    print("above ten")
    if x>20:
        print("and also 20")
    else:
        print("but not above ten")
# Out:
# above ten
# and also 20

# %% [markdown]
# i=1
# while i<6:
#     print(i)
#     i+=1

# %%
i=0
while i<6:
  i+=1
   if i==3:
continue
print(i)
# Out:
#   Cell In[93], line 4
#     if i==3:
#     ^
# IndentationError: unexpected indent

# %%
i=1
while i<6:
    print(i)
    i+=1
else:
    print("i is no longer than 6")
# Out:
# 1
# 2
# 3
# 4
# 5
# i is no longer than 6

# %%
def my_function(fname):
    print(fname+"Refsnes")
my_function("emil")
my_function("tobias")
my_function("linus")
# Out:
# emilRefsnes
# tobiasRefsnes
# linusRefsnes

# %%
usernma=input("enter the username:")
print("username is:"+username)
# Out:
# enter the username: hio

# %%
x=min(5,10,15)
y=max(5,10,25)
print(x)
print(y)
# Out:
# 5
# 25

# %%
x=abs(-7.25)
print(x)
# Out:
# 7.25

# %%
x=pow(4,3)
print(x)
# Out:
# 64

# %%
import math
x=math.sqrt(64)
print(x)
# Out:
# 8.0

# %%
import math
x=math.ceil(1.4)
y=math.floor(1.4)
print(x)
print(y)
# Out:
# 2
# 1
