# %%
print("hello world")
# Out:
# hello world

# %%
x=5
y="joh"
print(x)
print(y)
# Out:
# 5
# joh

# %%
x=4
x="sally"
print(x)
# Out:
# sally

# %%
x=str(3)
y=int(3)
z=float(3)
print(x)
print(y)
print(z)
# Out:
# 3
# 3
# 3.0

# %% [markdown]
# 2myvar="hi"
# my-var="hi"
# my var="hi"
# print(2myvar)
# print(my-var)
# print(my var)

# %%
my var="hi"


print(my var)
# Out:
#   Cell In[10], line 1
#     my var="hi"
#        ^
# SyntaxError: invalid syntax

# %%
myvar="JOhn"
print(myvar)
# Out:
# JOhn

# %%
my_var="John"
print(my_var)
# Out:
# John

# %%
_my_var="John"
print(_my_var)
# Out:
# John

# %%
myVar="john"
print(myVar)
# Out:
# john

# %%
MYVAR="john"
print(MYVAR)
# Out:
# john

# %% [markdown]
# ##

# %%
myvar2="john"
print(myvar2)
# Out:
# john

# %%
x,y,z="orange","mango","apple"
print(x)
print(y)

print(z)
# Out:
# orange
# mango
# apple

# %%
x=y=z="orange"
print(x)
print(y)
print(z)
# Out:
# orange
# orange
# orange

# %%
fruits=["apple","banana","cherry"]
x,y,z=fruits
x
print(x)
print(y)
print(z)
# Out:
# apple
# banana
# cherry

# %%
x="python"
y="is"
z="awesome"
print(x,y,z)
# Out:
# python is awesome

# %%
x="awesome"
def myfunc():
 print("python is "+x)
myfunc()
# Out:
# python is awesome

# %%
x="awesome"
def myfunc():
    x="fantastic"
print("python is" +x)
myfunc()
print("python is" +x)
# Out:
# python isawesome
# python isawesome
