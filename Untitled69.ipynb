# %%
#decision tree

# %%
import pandas  as pd
import matplotlib.pyplot as plt
import numpy as np
data=pd.read_csv("play_tennis.csv")
data
# Out:
#     day   outlook  temp humidity    wind play
# 0    D1     Sunny   Hot     High    Weak   No
# 1    D2     Sunny   Hot     High  Strong   No
# 2    D3  Overcast   Hot     High    Weak  Yes
# 3    D4      Rain  Mild     High    Weak  Yes
# 4    D5      Rain  Cool   Normal    Weak  Yes
# 5    D6      Rain  Cool   Normal  Strong   No
# 6    D7  Overcast  Cool   Normal  Strong  Yes
# 7    D8     Sunny  Mild     High    Weak   No
# 8    D9     Sunny  Cool   Normal    Weak  Yes
# 9   D10      Rain  Mild   Normal    Weak  Yes
# 10  D11     Sunny  Mild   Normal  Strong  Yes
# 11  D12  Overcast  Mild     High  Strong  Yes
# 12  D13  Overcast   Hot   Normal    Weak  Yes
# 13  D14      Rain  Mild     High  Strong   No

# %%
# House Price Prediction using Multiple Linear Regression

# Step 1: Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Step 2: Load dataset
df = pd.read_csv("house_data.csv")  # Replace with your path if needed
print("Dataset Preview:\n", df.head())

# Step 3: Define independent and dependent variables
X = df[['Size', 'Bedrooms', 'Bathrooms']]  # Features
y = df['Price']                            # Target

# Step 4: Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Step 5: Model training
model = LinearRegression()
model.fit(X_train, y_train)

# Step 6: Prediction
y_pred = model.predict(X_test)

# Step 7: Evaluation
print("\nIntercept:", model.intercept_)
print("Coefficients:", model.coef_)
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
print("R² Score:", r2_score(y_test, y_pred))

# Step 8: Visualization
plt.figure(figsize=(8, 5))
plt.plot(range(len(y_test)), y_test.values, label='Actual Price', marker='o')
plt.plot(range(len(y_pred)), y_pred, label='Predicted Price', marker='x')
plt.title("Actual vs Predicted House Prices")
plt.xlabel("Test Sample")
plt.ylabel("Price")
plt.legend()


plt.show()
# Out:
# Dataset Preview:
#     Size  Bedrooms  Bathrooms   Price
# 0  1000         2          1  200000
# 1  1200         2          2  220000
# 2  1500         3          2  260000
# 3  1800         3          2  300000
# 4  2000         3          3  330000
#
# Intercept: 55833.3333333332
# Coefficients: [ 1.41666667e+02 -1.94444444e+03 -8.86707758e-12]
# Mean Squared Error: 42631172.83950591
# R² Score: 0.9964767625752474

# %%
import pandas  as pd
import numpy as  np
import matplotlib.pyplot as plt
data=pd.read_csv("user_data.csv")
print("initial dataset shape:",data.shape)
print("\nNull values in each column:\n")
print(data.isnull().sum())
data_cleaned=data.dropna()
print("\n dataset shape after removing null values :",data_cleaned.shape)
# Out:
# initial dataset shape: (39, 5)
#
# Null values in each column:
#
# UserId           0
# UsageDuraiton    0
# Age              0
# Country          0
# TotalLikes       0
# dtype: int64
#
#  dataset shape after removing null values : (39, 5)
