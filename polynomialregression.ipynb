# %%
import pandas  as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# %%
data=pd.read_csv("Position_Salaries.csv")

# %%
data_set = pd.read_csv("Position_Salaries.csv")
x = data_set.iloc[:, 1:2].values
y = data_set.iloc[:, 2].values

# %%
# Polynomial Regression with degree 2
poly_regs = PolynomialFeatures(degree=2)
x_poly = poly_regs.fit_transform(x)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(x_poly,y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y,color="blue")
plt.scatter(x,lin_reg_2.predict(poly_regs.fit_transform(x)),color="red")
plt.title("polynomial Regression degree 2")
plt.xlabel("position level")
plt.ylabel("salary")
plt.show()

# %%
poly_pred = lin_reg_2.predict(poly_regs.fit_transform([[6.5]]))
print("Predicted Salary for level 6.5 (Degree 2):", poly_pred)
# Out:
# Predicted Salary for level 6.5 (Degree 2): [189498.10606061]

# %%
# Polynomial Regression with degree 3
poly_regs = PolynomialFeatures(degree=3)
x_poly = poly_regs.fit_transform(x)
lin_reg_3 = LinearRegression()
lin_reg_3.fit(x_poly, y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y,color="blue")
plt.scatter(x,lin_reg_3.predict(poly_regs.fit_transform(x)),color="red")
plt.title("polynomial Regression degree 3")
plt.xlabel("position level")
plt.ylabel("salary")
plt.show()

# %%
poly_pred = lin_reg_3.predict(poly_regs.fit_transform([[6.5]]))
print("Predicted Salary for level 6.5 (Degree 3):", poly_pred)
# Out:
# Predicted Salary for level 6.5 (Degree 3): [133259.46969697]

# %%
# Polynomial Regression with degree 4
poly_regs = PolynomialFeatures(degree=4)
x_poly = poly_regs.fit_transform(x)
lin_reg_4 = LinearRegression()
lin_reg_4.fit(x_poly, y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y,color="blue")
plt.scatter(x,lin_reg_4.predict(poly_regs.fit_transform(x)),color="red")
plt.title("polynomial Regression degree 4")
plt.xlabel("position level")
plt.ylabel("salary")
plt.show()

# %%
poly_pred = lin_reg_4.predict(poly_regs.fit_transform([[6.5]]))
print("Predicted Salary for level 6.5 (Degree 4):", poly_pred)
# Out:
# Predicted Salary for level 6.5 (Degree 4): [158862.45265153]

# %%
# Polynomial Regression with degree 4
poly_regs = PolynomialFeatures(degree=5)
x_poly = poly_regs.fit_transform(x)
lin_reg_5 = LinearRegression()
lin_reg_5.fit(x_poly, y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y,color="blue")
plt.scatter(x,lin_reg_5.predict(poly_regs.fit_transform(x)),color="red")
plt.title("polynomial Regression degree 4")
plt.xlabel("position level")
plt.ylabel("salary")
plt.show()

# %%
poly_pred = lin_reg_5.predict(poly_regs.fit_transform([[6.5]]))
print("Predicted Salary for level 6.5 (Degree 5):", poly_pred)
# Out:
# Predicted Salary for level 6.5 (Degree 5): [174878.07765127]

# %%
import pandas  as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# %%
data=pd.read_csv("Position_Salaries.csv")

# %%
x=data.iloc[: , 1:2].values
y=data.iloc[:,2].values

# %%
poly_regs=PolynomialFeatures(degree=2)
x_poly=poly_regs.fit_transform(x)
lin_reg_2=LinearRegression()
lin_reg_2.fit(x_poly,y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y,color="red")
plt.scatter(x,lin_reg_2.predict(poly_regs.fit_transform(x)),color="black")
plt.title("polynomial tegression degree 2")
plt.xlabel("position level")
plt.ylabel("salary")
plt.show()

# %%
ploty_pred=lin_reg_2.predict(poly.regs.fit_transform([[6.5]]))
print("predic
