# %%
import pandas  as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("user_data.csv")

# %%
x=data['X']
y=data['Y']

# %%
plt.scatter(x,y,color='purple',marker='o')
plt.title("sactter plot from csv file")
plt.xlabel("x values")
plt.ylabel("y label")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 plt.scatter(x,y,color='purple',marker='o')
#       2 plt.title("sactter plot from csv file")
#       3 plt.xlabel("x values")
#
# NameError: name 'x' is not defined
