# %%
print("hii")
# Out:
# hii

# %%
str="i am rajgauri"
print(str)
# Out:
# i am rajgauri

# %%
str='hi'
print(str)
# Out:
# hi

# %%
str="'hi'"
print(str)
# Out:
# 'hi'

# %%
str='''hi'''
print(str)
# Out:
# hi

# %%
str="rajgauri"
print(str[0:5])
# Out:
# rajga

# %%
str="rajgauri"
print(str[-3])
# Out:
# u

# %%
str="rajgauri"
print(str[::-1])
# Out:
# iruagjar

# %%
str="abcde"
str="".join(reversed(str))
print(str)
# Out:
# edcba

# %%
str="rajgauri bhilare"
print("initial string:")
print(str)
# Out:
# initial string:
# rajgauri bhilare

# %%
str="hiii,stay happy"

# %%
print("first string:")
print(str)
# Out:
# first string:
# hiii,stay happy

# %%
str="welcome to my life"
print("update string")
# Out:
# update string

# %%
print(str)
# Out:
# welcome to my life
