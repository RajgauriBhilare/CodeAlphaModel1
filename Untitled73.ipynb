# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.19.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
from sklearn.metrics import mean_squared_error

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.3-cp39-cp39-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.2.3-cp39-cp39-win_amd64.whl (11.6 MB)
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.6 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/11.6 MB 2.8 MB/s eta 0:00:04
#    ------ --------------------------------- 1.8/11.6 MB 3.0 MB/s eta 0:00:04
#    --------- ------------------------------ 2.6/11.6 MB 3.3 MB/s eta 0:00:03
#    ------------ --------------------------- 3.7/11.6 MB 3.8 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.7/11.6 MB 4.0 MB/s eta 0:00:02
#    ------------------- -------------------- 5.8/11.6 MB 4.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.6/11.6 MB 4.1 MB/s eta 0:00:02
#    ------------------------ --------------- 7.1/11.6 MB 4.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.4/11.6 MB 4.1 MB/s eta 0:00:01
#    ------------------------------- -------- 9.2/11.6 MB 4.1 MB/s eta 0:00:01
#    ------------------------------------ --- 10.5/11.6 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.6 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 4.3 MB/s eta 0:00:00
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.3 pytz-2025.2 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.9.4-cp39-cp39-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.0-cp39-cp39-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.57.0-cp39-cp39-win_amd64.whl.metadata (104 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.7-cp39-cp39-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from matplotlib) (24.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.1.0-cp39-cp39-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Collecting importlib-resources>=3.2.0 (from matplotlib)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: six>=1.5 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.9.4-cp39-cp39-win_amd64.whl (7.8 MB)
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.8 MB 1.4 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.0/7.8 MB 1.9 MB/s eta 0:00:04
#    -------- ------------------------------- 1.6/7.8 MB 2.0 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.1/7.8 MB 2.3 MB/s eta 0:00:03
#    -------------- ------------------------- 2.9/7.8 MB 2.4 MB/s eta 0:00:03
#    -------------------- ------------------- 3.9/7.8 MB 2.8 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.5/7.8 MB 2.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.5/7.8 MB 3.0 MB/s eta 0:00:01
#    --------------------------------- ------ 6.6/7.8 MB 3.2 MB/s eta 0:00:01
#    ------------------------------------ --- 7.1/7.8 MB 3.2 MB/s eta 0:00:01
#    ------------------------------------- -- 7.3/7.8 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 7.8/7.8 MB 2.9 MB/s eta 0:00:00
# Downloading contourpy-1.3.0-cp39-cp39-win_amd64.whl (211 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.57.0-cp39-cp39-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.2 MB 2.8 MB/s eta 0:00:01
#    ------------------- -------------------- 1.0/2.2 MB 3.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.6/2.2 MB 3.2 MB/s eta 0:00:01
#    --------------------------------- ------ 1.8/2.2 MB 2.9 MB/s eta 0:00:01
#    --------------------------------- ------ 1.8/2.2 MB 2.9 MB/s eta 0:00:01
#    -------------------------------------- - 2.1/2.2 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 1.6 MB/s eta 0:00:00
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading kiwisolver-1.4.7-cp39-cp39-win_amd64.whl (55 kB)
# Downloading pillow-11.1.0-cp39-cp39-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.6 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.6 MB 840.2 kB/s eta 0:00:03
#    ------- -------------------------------- 0.5/2.6 MB 840.2 kB/s eta 0:00:03
#    --------------- ------------------------ 1.0/2.6 MB 1.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 1.6/2.6 MB 1.4 MB/s eta 0:00:01
#    ------------------------------- -------- 2.1/2.6 MB 1.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.4/2.6 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 1.7 MB/s eta 0:00:00
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.0 cycler-0.12.1 fonttools-4.57.0 importlib-resources-6.5.2 kiwisolver-1.4.7 matplotlib-3.9.4 pillow-11.1.0 pyparsing-3.2.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sklearn
# Out:
# Collecting sklearn
#   Downloading sklearn-0.0.post12.tar.gz (2.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [15 lines of output]
#   The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#   rather than 'sklearn' for pip commands.
#
#   Here is how to fix this error in the main use cases:
#   - use 'pip install scikit-learn' rather than 'pip install sklearn'
#   - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#     (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#   - if the 'sklearn' package is used by one of your dependencies,
#     it would be great if you take some time to track which package uses
#     'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#   - as a last resort, set the environment variable
#     SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#   More information is available at
#   https://github.com/scikit-learn/sklearn-pypi-package
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
pip install numpy pandas matplotlib scikit-learn tensorflow keras
# Out:
# Requirement already satisfied: numpy in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (2.0.2)
# Requirement already satisfied: pandas in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (3.9.4)
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp39-cp39-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: tensorflow in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (2.19.0)
# Requirement already satisfied: keras in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (3.9.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from matplotlib) (6.5.2)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.13.1-cp39-cp39-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from tensorflow) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: rich in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from keras) (14.0.0)
# Requirement already satisfied: namex in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from keras) (0.0.8)
# Requirement already satisfied: optree in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from keras) (0.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from rich->keras) (2.19.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.19.0->tensorflow) (8.6.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\rajguru\anaconda3\envs\stockenv\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Downloading scikit_learn-1.6.1-cp39-cp39-win_amd64.whl (11.2 MB)
#    ---------------------------------------- 0.0/11.2 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/11.2 MB 6.1 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.9/11.2 MB 7.0 MB/s eta 0:00:02
#    --------------- ------------------------ 4.5/11.2 MB 7.1 MB/s eta 0:00:01
#    ------------------- -------------------- 5.5/11.2 MB 7.0 MB/s eta 0:00:01
#    ------------------------ --------------- 6.8/11.2 MB 6.8 MB/s eta 0:00:01
#    ------------------------------ --------- 8.4/11.2 MB 6.7 MB/s eta 0:00:01
#    --------------------------------- ------ 9.4/11.2 MB 6.5 MB/s eta 0:00:01
#    -------------------------------------- - 10.7/11.2 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.2/11.2 MB 6.3 MB/s eta 0:00:00
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading scipy-1.13.1-cp39-cp39-win_amd64.whl (46.2 MB)
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
#    - -------------------------------------- 1.6/46.2 MB 7.0 MB/s eta 0:00:07
#    -- ------------------------------------- 3.1/46.2 MB 7.7 MB/s eta 0:00:06
#    ---- ----------------------------------- 4.7/46.2 MB 7.9 MB/s eta 0:00:06
#    ----- ---------------------------------- 6.8/46.2 MB 8.2 MB/s eta 0:00:05
#    ------- -------------------------------- 8.9/46.2 MB 8.4 MB/s eta 0:00:05
#    --------- ------------------------------ 10.7/46.2 MB 8.5 MB/s eta 0:00:05
#    ---------- ----------------------------- 12.1/46.2 MB 8.2 MB/s eta 0:00:05
#    ----------- ---------------------------- 13.6/46.2 MB 8.0 MB/s eta 0:00:05
#    ------------- -------------------------- 15.7/46.2 MB 8.2 MB/s eta 0:00:04
#    --------------- ------------------------ 17.8/46.2 MB 8.3 MB/s eta 0:00:04
#    ---------------- ----------------------- 19.4/46.2 MB 8.2 MB/s eta 0:00:04
#    ------------------ --------------------- 21.2/46.2 MB 8.3 MB/s eta 0:00:04
#    ------------------- -------------------- 22.8/46.2 MB 8.2 MB/s eta 0:00:03
#    --------------------- ------------------ 24.4/46.2 MB 8.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 25.7/46.2 MB 8.0 MB/s eta 0:00:03
#    ----------------------- ---------------- 27.0/46.2 MB 7.9 MB/s eta 0:00:03
#    ------------------------ --------------- 28.0/46.2 MB 7.7 MB/s eta 0:00:03
#    ------------------------- -------------- 29.9/46.2 MB 7.7 MB/s eta 0:00:03
#    -------------------------- ------------- 31.2/46.2 MB 7.6 MB/s eta 0:00:02
#    ---------------------------- ----------- 32.8/46.2 MB 7.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 34.3/46.2 MB 7.7 MB/s eta 0:00:02
#    ------------------------------ --------- 35.7/46.2 MB 7.6 MB/s eta 0:00:02
#    -------------------------------- ------- 37.2/46.2 MB 7.6 MB/s eta 0:00:02
#    --------------------------------- ------ 38.8/46.2 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 40.1/46.2 MB 7.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 41.4/46.2 MB 7.5 MB/s eta 0:00:01
#    ------------------------------------ --- 42.5/46.2 MB 7.4 MB/s eta 0:00:01
#    ------------------------------------- -- 43.8/46.2 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------  45.4/46.2 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------- 46.2/46.2 MB 7.2 MB/s eta 0:00:00
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.6.1 scipy-1.13.1 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.
