# %%
n=int(input("enter a positive integer n:"))
sum_of_numbers=n*(n+1)//2
print(f"the sum of the first {n} positive integee is:{sum_of_numbers}")
# Out:
# enter a positive integer n: 10
# the sum of the first 10 positive integee is:55

# %%
n=int(input("enter numbers "))
sum_of_numbers=n*(n+1)//2
print(sum_of_numbers)
# Out:
# enter numbers  10
# 55

# %%
string=input("enter a string:")
char_to_count=input("enter a which want to count:")
count=string.count(char_to_count)
print(f"The charachter'{char_to_count}'appers {count} times in the string.")
# Out:
# enter a string: hiiiii
# enter a which want to count: i
# The charachter'i'appers 5 times in the string.

# %%
my_tuple=(1,2,3,4,5,6,7,8,4)
print("create tuple is:",my_tuple)

print("first element:",my_tuple[0])
print("last tuple is:",my_tuple[-1])

print("tuple length is:",len(my_tuple))

mixed_tuple=(1,"hii",9090,True)
print(mixed_tuple)
# Out:
# create tuple is: (1, 2, 3, 4, 5, 6, 7, 8, 4)
# first element: 1
# last tuple is: 4
# tuple length is: 9
# (1, 'hii', 9090, True)

# %%
my_tuple=('A','b','R','b','T','j')
tuple_to_string=''.join(my_tuple)
print("the converted string is:",tuple_to_string)
# Out:
# the converted string is: AbRbTj

# %%
my_list=[1,2,3,4,5]
my_tuple=tuple(my_list)
print("the list is:",my_list)
print("converted is:",my_tuple)
# Out:
# the list is: [1, 2, 3, 4, 5]
# converted is: (1, 2, 3, 4, 5)

# %%
numbers=[10,12,85,9.4,45,56,85,10,20,00,79,552214,45]
largest_number=max(numbers)
smallest_number=min(numbers)
print("the list is:",numbers)
print("largest number is:",largest_number)
print("smallest number is:",smallest_number)
# Out:
# the list is: [10, 12, 85, 9.4, 45, 56, 85, 10, 20, 0, 79, 552214, 45]
# largest number is: 552214
# smallest number is: 0

# %%
n=int(input("enter the 1st no"))
n1=int(input("enter 2nd no"))
addition=n+n1
print(addition)

substraction=n-n1
print(substraction)

if n1!=0:
    division=n/n1
    print(division)
# Out:
# enter the 1st no 5
# enter 2nd no 5
# 10
# 0
# 1.0

# %%
n=int(input("enter number="))
rev=0
while n!=0:
    digit=int(n%10)
    rev=rev*10+digit
    n=n//10
print("reverse of given number is =",rev)
print(n)
# Out:
# enter number= 123
# reverse of given number is = 321
# 0

# %%
n=int(input("enter the number:"))
rev=0
temp=n
while temp!=0:
    digit=int(temp%10)
    rev=rev*10+digit
    temp=temp//10
print("reverse of given is =",rev)
if rev==n:
    print("number is palidrome ")
else:
    print("not")
print(rev)
print(n)
# Out:
# enter the number: 111
# reverse of given is = 111
# number is palidrome
# 111
# 111

# %%
n=int(input("enter the  number:"))
count=0
for i in range(1,n):
    if n%i==0:
        count=count+i
if n==count:
    print("given number is perfect")
else :
    print("given number is not perfect")
count

# %%
n=int(input("enter number"))
n=int(input())
s=n
b=len("%s"%n)
sum1=0
while n!=0:
    r=n%10
sum1=sum1+(r**b)
n=n//10
if s==sum1:
    print("the given number",s,"is armstrong number")
else:
    print("the given number",s,"is not armstrong number")
# Out:
# enter number 12
#  23

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
data_set=pd.read_csv("C:/Users/Rajguru/Downloads/MBA.csv")


x = data_set.iloc[:, [2, 3]].values
y = data_set.iloc[:, 4].values


from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

from sklearn.preprocessing import StandardScaler
st_x=StandardScaler()
x_train=st_x.fit_transform(x_train)
x_test=st_x.transform(x_test)

from sklearn.neighbors import KNeighborsClassifier
classifier=KNeighborsClassifier(n_neighbors=5,metric='minkowski',p=2)
classifier.fit(x_train, y_train)
y_pred=classifier.predict(x_test)
print(y_pred)
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# ['Humanities' 'Business' 'STEM' ... 'Humanities' 'Business' 'Business']
# [[167 195  69]
#  [218 269 104]
#  [178 255  94]]
