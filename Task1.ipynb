# %%
import pandas as pd

df = pd.read_csv("C:/Users/Rajguru/Downloads/Dataset .csv")
df.head()  # Check the first few rows of data
df.info()  # Check column names, data types, and missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.isnull().sum()  # Count missing values for each column
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
#Task One
import pandas as pd

# Load the dataset
df = pd.read_csv("C:/Users/Rajguru/Downloads/Dataset .csv")

# Count occurrences of each cuisine
cuisine_counts = df['Cuisines'].value_counts()

# Get the top 3 cuisines
top_3_cuisines = cuisine_counts.head(3)

# Display the result
print("Top 3 Cuisines:")
print(top_3_cuisines)
# Out:
# Top 3 Cuisines:
# Cuisines
# North Indian             936
# North Indian, Chinese    511
# Chinese                  354
# Name: count, dtype: int64

# %%
import pandas as pd
data = pd.read_csv("C:/Users/Rajguru/Downloads/Dataset .csv")
# Count occurrences of each cuisine
cuisine_counts = data['Cuisines'].value_counts()

# Get the top 3 cuisines
top_3_cuisines = cuisine_counts.head(3)

# Calculate total number of restaurants
total_restaurants = len(data)

# Calculate percentage for each of the top 3 cuisines
top_3_cuisines_percentage = (top_3_cuisines / total_restaurants) * 100

# Display the result
result = top_3_cuisines_percentage.reset_index()
result.columns = ['Cuisine', 'Percentage']
print("Percentage of Restaurants Serving Top Cuisines:")
print(result)
# Out:
# Percentage of Restaurants Serving Top Cuisines:
#                  Cuisine  Percentage
# 0           North Indian    9.800021
# 1  North Indian, Chinese    5.350225
# 2                Chinese    3.706418

# %% [markdown]
# North Indian Cuisine:
#
# The most popular cuisine, served by about 9.8% of restaurants.
# North Indian and Chinese Combination:
#
# About 5.35% of restaurants serve both North Indian and Chinese cuisines together, showing that this combination is quite popular.
# Chinese Cuisine:
#
# Chinese cuisine alone is served by 3.71% of restaurants, making it the third most common choice.

# %%
#Task 1.2

# %%
import pandas as pd

# Load the dataset
data = pd.read_csv("C:/Users/Rajguru/Downloads/Dataset .csv")
# Step 1: Count occurrences of each city
city_counts = data['City'].value_counts()

# Step 2: Identify the city with the highest number of restaurants
top_city = city_counts.idxmax()
top_city_count = city_counts.max()

# Step 3: Display the result
print(f"The city with the highest number of restaurants is: {top_city}")
print(f"Number of restaurants: {top_city_count}")
# Out:
# The city with the highest number of restaurants is: New Delhi
# Number of restaurants: 5473

# %%
import pandas as pd


# Display the unique rating types in the column
rating_types = data['Rating text'].unique()

print("Distinct Rating Types in the Dataset:")
print(rating_types)
# Out:
# Distinct Rating Types in the Dataset:
# ['Excellent' 'Very Good' 'Good' 'Average' 'Not rated' 'Poor']

# %%
import pandas as pd
data = pd.read_csv("C:/Users/Rajguru/Downloads/Dataset .csv")
# Step 1: Define the mapping for text to numeric ratings
rating_mapping = {
    "Excellent": 5,
    "Very Good": 4,
    "Good": 3,
    "Average": 2,
    "Not rated": 1,
    "Poor": 0
}

# Step 2: Convert text ratings to numeric ratings
data['Numeric_Rating'] = data['Rating text'].map(rating_mapping)

# Step 3: Verify the conversion
print("Dataset with Numeric Ratings:")
print(data[['Rating text', 'Numeric_Rating']].head())
# Out:
# Dataset with Numeric Ratings:
#   Rating text  Numeric_Rating
# 0   Excellent               5
# 1   Excellent               5
# 2   Very Good               4
# 3   Excellent               5
# 4   Excellent               5

# %%
import pandas as pd

# Step 1: Load the dataset
data = pd.read_csv("C:/Users/Rajguru/Downloads/Dataset .csv")  # Replace with your actual dataset path

# Step 2: Define the mapping for text to numeric ratings (6-point scale)
rating_mapping = {
    "Poor": 0,
    "Not rated": 1,
    "Average": 2,
    "Good": 3,
    "Very Good": 4,
    "Excellent": 5
}

# Step 3: Convert text ratings to numeric ratings and store them in a new column
data['Numeric_Rating'] = data['Rating text'].map(rating_mapping)

# Step 4: Verify the conversion by showing both Rating text and Numeric_Rating columns
print("Dataset with Textual Ratings and Corresponding Numeric Ratings:")
print(data[['Rating text', 'Numeric_Rating']].head())

# Optional: Save the updated dataset to a new CSV file
data.to_csv("C:/Users/Rajguru/Downloads/Dataset_with_Updated_Ratings.csv", index=False)
# Out:
# Dataset with Textual Ratings and Corresponding Numeric Ratings:
#   Rating text  Numeric_Rating
# 0   Excellent               5
# 1   Excellent               5
# 2   Very Good               4
# 3   Excellent               5
# 4   Excellent               5

# %%
import pandas as pd

# Step 1: Load the dataset
data = pd.read_csv("C:/Users/Rajguru/Downloads/Dataset .csv")  # Replace with your actual dataset path

# Step 2: Define the mapping for text to numeric ratings
rating_mapping = {
    "Poor": 0,
    "Not rated": 1,
    "Average": 2,
    "Good": 3,
    "Very Good": 4,
    "Excellent": 5
}

# Step 3: Convert text ratings to numeric ratings and store them in a new column
data['Numeric_Rating'] = data['Rating text'].map(rating_mapping)

# Step 4: Check if the 'Rating text' column has been mapped correctly
print("Dataset with Updated Numeric Ratings:")
print(data[['Rating text', 'Numeric_Rating']].head())
# Out:
# Dataset with Updated Numeric Ratings:
#   Rating text  Numeric_Rating
# 0   Excellent               5
# 1   Excellent               5
# 2   Very Good               4
# 3   Excellent               5
# 4   Excellent               5

# %%
import pandas as pd
data = pd.read_csv("C:/Users/Rajguru/Downloads/Dataset .csv")
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
import pandas as pd

# Load the dataset
file_path = "C:/Users/Rajguru/Downloads/Dataset .csv"  # Replace with the actual file path
data = pd.read_csv(file_path)

# Calculate the average rating for restaurants in each city
average_rating_by_city = data.groupby("City")["Aggregate rating"].mean().reset_index()

# Sort the results for better readability
average_rating_by_city = average_rating_by_city.sort_values(by="Aggregate rating", ascending=False)

# Display the results
print(average_rating_by_city)

# Optionally save the results to a new CSV file
average_rating_by_city.to_csv("average_rating_by_city.csv", index=False)
# Out:
#                  City  Aggregate rating
# 56         Inner City          4.900000
# 107       Quezon City          4.800000
# 73        Makati City          4.650000
# 95         Pasig City          4.633333
# 75   Mandaluyong City          4.625000
# ..                ...               ...
# 88          New Delhi          2.438845
# 83          Montville          2.400000
# 78          Mc Millan          2.400000
# 89              Noida          2.036204
# 43          Faridabad          1.866932
#
# [141 rows x 2 columns]

# %%
#level 1 task 1.2
# Calculate the average rating for restaurants in each city
average_rating_by_city = data.groupby("City")["Aggregate rating"].mean().reset_index()

# Find the city with the highest average rating
highest_rated_city = average_rating_by_city.loc[average_rating_by_city["Aggregate rating"].idxmax()]

# Display the city with the highest average rating
print("City with the highest average rating:")
print(highest_rated_city)
# Out:
# City with the highest average rating:
# City                Inner City
# Aggregate rating           4.9
# Name: 56, dtype: object

# %%
#level 1 task 3.1
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Create a bar chart for the distribution of price ranges
plt.figure(figsize=(10, 6))
sns.countplot(x="Price range", data=data, palette="viridis")

# Add labels and title
plt.title("Distribution of Price Ranges Among Restaurants", fontsize=16)
plt.xlabel("Price Range", fontsize=12)
plt.ylabel("Number of Restaurants", fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Rajguru\AppData\Local\Temp\ipykernel_11044\2608116723.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Price range", data=data, palette="viridis")

# %%
# Create a bar chart for the distribution of price ranges
plt.figure(figsize=(12, 7))
ax = sns.countplot(x="Price range", data=data, palette="viridis")

# Add annotations (count above bars)
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{int(height)}', 
                (p.get_x() + p.get_width() / 2., height), 
                ha='center', va='bottom', fontsize=10, color='black')

# Add labels and title
plt.title("Distribution of Price Ranges Among Restaurants", fontsize=16)
plt.xlabel("Price Range", fontsize=12)
plt.ylabel("Number of Restaurants", fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Rajguru\AppData\Local\Temp\ipykernel_11044\894841034.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x="Price range", data=data, palette="viridis")

# %%
# Count the number of restaurants in each price range
price_range_counts = data['Price range'].value_counts()

# Calculate the total number of restaurants
total_restaurants = len(data)

# Calculate the percentage for each price range
percentage_price_range = (price_range_counts / total_restaurants) * 100

# Create a new DataFrame to display ranges and their percentages separately
result = pd.DataFrame({
    'Price_Range': price_range_counts.index,
    'Percentage': percentage_price_range.values
})

# Display the result
print(result)
# Out:
#    Price_Range  Percentage
# 0            1   46.529159
# 1            2   32.593446
# 2            3   14.741912
# 3            4    6.135483

# %%
# Calculate the percentage of restaurants offering online delivery
percentage = (data['Has Online delivery'].value_counts(normalize=True)['Yes']) * 100

# Print the result
print(f"Percentage of restaurants offering online delivery: {percentage:.2f}%")
# Out:
# Percentage of restaurants offering online delivery: 25.66%

# %%
# Calculate average ratings
avg_rating_with_delivery = data[data['Has Online delivery'] == 'Yes']['Aggregate rating'].mean()
avg_rating_without_delivery = data[data['Has Online delivery'] == 'No']['Aggregate rating'].mean()

# Print the results
print(f"Average rating (with online delivery): {avg_rating_with_delivery:.2f}")
print(f"Average rating (without online delivery): {avg_rating_without_delivery:.2f}")
# Out:
# Average rating (with online delivery): 3.25
# Average rating (without online delivery): 2.47
