# %%
import statistics

numbers = [1, 2, 3, 4, 5]
median = statistics.median(numbers)
print("Median:", median)
# Out:
# Median: 3

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install statistics
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for statistics: filename=statistics-1.0.3.5-py3-none-any.whl size=7450 sha256=5cc780a687a36a690754d305d5bc99be0171acf28850cedc0ec7d794c046bb1a
#   Stored in directory: c:\users\rajguru\appdata\local\pip\cache\wheels\10\9c\1a\0c68a89e4533a18e9f9902018b94ffc2481139818b67cbb05a
# Successfully built statistics
# ...
# Note: you may need to restart the kernel to use updated packages.
